# %% [markdown]
# ## 数值计算

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(0,16,1920)
y = np.linspace(0,16,1080)
xx,yy = np.meshgrid(x,y)

z = xx*yy
c = z.astype(int)

plt.imshow(c,cmap='gray')
plt.show()
